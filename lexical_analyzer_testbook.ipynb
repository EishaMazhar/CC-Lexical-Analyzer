# %%
import string
import re
import pprint

# %%
class Token:
    tokens = {'keyword': ('KEYWORD', ("program", "var", "div", "integer", "real", "begin", "end",
                                      "procedure", "if", "then", "else", "while", "repeat", "until",
                                      "write", "writeln", "or",
                                      "and","div", "mod", "not", "trunc", "real", "do")),
              'id': 'ID', 'sym':'SYM', 'intconst':'INTCONST', 'readconst':'READCONST',
              'strconst':'STRCONST', 'assign': 'ASSIGN', 'colon': 'COLON', 'comma': 'COMMA',
              'semicolon': 'SEMICOLON', 'dot': 'DOT', 'eq': 'EQ', 'nq': 'NQ', 'lt': 'LT',
              'lte': 'LTE', 'gt': 'GT', 'gte': 'GTE', 'quote': 'QUOTE', 'integer': 'INTEGER', 
              'plus': 'PLUS', 'minus': 'MINUS', 'mul': 'MUL', 'div': 'DIV', 'lparen': 'LPAREN', 
               'rparen': 'RPAREN', 'eof': 'EOF', 'term': 'TERM', 'and': 'AND', 'or': 'OR', 'not': 'NOT'}
    
    token_type = ''
    lexeme = ''
    line_no = -1
    position = -1
    
    def __init__(self, token_type, lexeme, line_no, position):
        self.token_type = token_type
        self.lexeme = lexeme
        self.line_no = line_no
        self.position = position

# %%
source_text = ""
with open("source_code.pas", 'r') as source_file:
    source_text = "".join(source_file.readlines())
source_file.close()

print(source_text)
# Out:
# program checkMyAbility;
# var
# counter: integer;
# number: integer;
# factorial: integer;
# height : real;
# width : real;
# breadth : real;
# volume : real;
# begin
# number := 6;
# counter := number;
# factorial := 1
# while counter > 0 do begin
# number := number * counter;
# counter := counter - 1;
# end;
# height := 8.5;
# width := 4.5;
# breadth := 2.25;
# volume := height * width * breadth;
# if volume >= 100 and number < 5 then begin
# volume := volume / 4;
# end
# else begin
# if volume >= 50 or number < 10 then begin
# volume := volume / 2;
# end
# end;
# write("Factorial of ");
# write(number);
# write(" is ");
# writeln(factorial);
# write("Some odd value is: ");
# writeln(volume);
# end.

# %%
print(tokens['keyword'][1])
print(tokens.keys())
# Out:
# ('program', 'var', 'div', 'integer', 'real', 'begin', 'end', 'procedure', 'if', 'then', 'else', 'while', 'repeat', 'until', 'write', 'writeln', 'or', 'and', 'div', 'mod', 'not', 'trunc', 'real', 'do')
# dict_keys(['keyword', 'ID', 'sym', 'intconst', 'readconst', 'strconst', ':=', ':', ',', ';', '.', 'eq', '!=', '<', '<=', '>', '>=', 'quote', 'integer', '+', '-', '*', '/', '(', ')', 'eof', 'term', 'AND', 'OR', 'not'])

# %%
def isID(token):
    id = re.match("[a-zA-Z]([a-zA-Z]|[0-9])*", token)
    return id

# def isToken(token):
#     token = re.match("[program|]")

def isDigit(dig):
    digit = re.match("[0-9]", dig)
    return digit

def isLetter(letter):
    alphabet = re.match("[a-zA-Z]", letter)
    return alphabet
    

def isKeyword(token):
    return

# %%
for i in range(len(code_lines)):
    
    print(i, code_lines[i])
    j=0   
    while(j < len(code_lines[i])): 
        print(code_lines[i][j])
        
        single_char = code_lines[i][j]
        
        j+=1
# Out:
# 0 program checkMyAbility;
# p
# alnum p
# r
# alnum r
# o
# alnum o
# g
# alnum g
# r
# alnum r
# a
# alnum a
# m
# alnum m
#
# c
# alnum c
# h
# alnum h
# e
# alnum e
# c
# alnum c
# k
# alnum k
# M
# alnum M
# y
# alnum y
# A
# alnum A
# b
# alnum b
# i
# alnum i
# l
# alnum l
# i
# alnum i
# t
# alnum t
# y
# alnum y
# ;
# 1 var
# v
# alnum v
# a
# alnum a
# r
# alnum r
# 2 counter: integer;
# c
# alnum c
# o
# alnum o
# u
# alnum u
# n
# alnum n
# t
# alnum t
# e
# alnum e
# r
# alnum r
# :
#
# i
# alnum i
# n
# alnum n
# t
# alnum t
# e
# alnum e
# g
# alnum g
# e
# alnum e
# r
# alnum r
# ;
# 3 number: integer;
# n
# alnum n
# u
# alnum u
# m
# alnum m
# b
# alnum b
# e
# alnum e
# r
# alnum r
# :
#
# i
# alnum i
# n
# alnum n
# t
# alnum t
# e
# alnum e
# g
# alnum g
# e
# alnum e
# r
# alnum r
# ;
# 4 factorial: integer;
# f
# alnum f
# a
# alnum a
# c
# alnum c
# t
# alnum t
# o
# alnum o
# r
# alnum r
# i
# alnum i
# a
# alnum a
# l
# alnum l
# :
#
# i
# alnum i
# n
# alnum n
# t
# alnum t
# e
# alnum e
# g
# alnum g
# e
# alnum e
# r
# alnum r
# ;
# 5 height : real;
# h
# alnum h
# e
# alnum e
# i
# alnum i
# g
# alnum g
# h
# alnum h
# t
# alnum t
#
# :
#
# r
# alnum r
# e
# alnum e
# a
# alnum a
# l
# alnum l
# ;
# 6 width : real;
# w
# alnum w
# i
# alnum i
# d
# alnum d
# t
# alnum t
# h
# alnum h
#
# :
#
# r
# alnum r
# e
# alnum e
# a
# alnum a
# l
# alnum l
# ;
# 7 breadth : real;
# b
# alnum b
# r
# alnum r
# e
# alnum e
# a
# alnum a
# d
# alnum d
# t
# alnum t
# h
# alnum h
#
# :
#
# r
# alnum r
# e
# alnum e
# a
# alnum a
# l
# alnum l
# ;
# 8 volume : real;
# v
# alnum v
# o
# alnum o
# l
# alnum l
# u
# alnum u
# m
# alnum m
# e
# alnum e
#
# :
#
# r
# alnum r
# e
# alnum e
# a
# alnum a
# l
# alnum l
# ;
# 9 begin
# b
# alnum b
# e
# alnum e
# g
# alnum g
# i
# alnum i
# n
# alnum n
# 10 number := 6;
# n
# alnum n
# u
# alnum u
# m
# alnum m
# b
# alnum b
# e
# alnum e
# r
# alnum r
#
# :
# =
#
# 6
# alnum 6
# ;
# 11 counter := number;
# c
# alnum c
# o
# alnum o
# u
# alnum u
# n
# alnum n
# t
# alnum t
# e
# alnum e
# r
# alnum r
#
# :
# =
#
# n
# alnum n
# u
# alnum u
# m
# alnum m
# b
# alnum b
# e
# alnum e
# r
# alnum r
# ;
# 12 factorial := 1
# f
# alnum f
# a
# alnum a
# c
# alnum c
# t
# alnum t
# o
# alnum o
# r
# alnum r
# i
# alnum i
# a
# alnum a
# l
# alnum l
#
# :
# =
#
# 1
# alnum 1
# 13 while counter > 0 do begin
# w
# alnum w
# h
# alnum h
# i
# alnum i
# l
# alnum l
# e
# alnum e
#
# c
# alnum c
# o
# alnum o
# u
# alnum u
# n
# alnum n
# t
# alnum t
# e
# alnum e
# r
# alnum r
#
# >
#
# 0
# alnum 0
#
# d
# alnum d
# o
# alnum o
#
# b
# alnum b
# e
# alnum e
# g
# alnum g
# i
# alnum i
# n
# alnum n
# 14 number := number * counter;
# n
# alnum n
# u
# alnum u
# m
# alnum m
# b
# alnum b
# e
# alnum e
# r
# alnum r
#
# :
# =
#
# n
# alnum n
# u
# alnum u
# m
# alnum m
# b
# alnum b
# e
# alnum e
# r
# alnum r
#
# *
#
# c
# alnum c
# o
# alnum o
# u
# alnum u
# n
# alnum n
# t
# alnum t
# e
# alnum e
# r
# alnum r
# ;
# 15 counter := counter - 1;
# c
# alnum c
# o
# alnum o
# u
# alnum u
# n
# alnum n
# t
# alnum t
# e
# alnum e
# r
# alnum r
#
# :
# =
#
# c
# alnum c
# o
# alnum o
# u
# alnum u
# n
# alnum n
# t
# alnum t
# e
# alnum e
# r
# alnum r
#
# -
#
# 1
# alnum 1
# ;
# 16 end;
# e
# alnum e
# n
# alnum n
# d
# alnum d
# ;
# 17 height := 8.5;
# h
# alnum h
# e
# alnum e
# i
# alnum i
# g
# alnum g
# h
# alnum h
# t
# alnum t
#
# :
# =
#
# 8
# alnum 8
# .
# 5
# alnum 5
# ;
# 18 width := 4.5;
# w
# alnum w
# i
# alnum i
# d
# alnum d
# t
# alnum t
# h
# alnum h
#
# :
# =
#
# 4
# alnum 4
# .
# 5
# alnum 5
# ;
# 19 breadth := 2.25;
# b
# alnum b
# r
# alnum r
# e
# alnum e
# a
# alnum a
# d
# alnum d
# t
# alnum t
# h
# alnum h
#
# :
# =
#
# 2
# alnum 2
# .
# 2
# alnum 2
# 5
# alnum 5
# ;
# 20 volume := height * width * breadth;
# v
# alnum v
# o
# alnum o
# l
# alnum l
# u
# alnum u
# m
# alnum m
# e
# alnum e
#
# :
# =
#
# h
# alnum h
# e
# alnum e
# i
# alnum i
# g
# alnum g
# h
# alnum h
# t
# alnum t
#
# *
#
# w
# alnum w
# i
# alnum i
# d
# alnum d
# t
# alnum t
# h
# alnum h
#
# *
#
# b
# alnum b
# r
# alnum r
# e
# alnum e
# a
# alnum a
# d
# alnum d
# t
# alnum t
# h
# alnum h
# ;
# 21 if volume >= 100 and number < 5 then begin
# i
# alnum i
# f
# alnum f
#
# v
# alnum v
# o
# alnum o
# l
# alnum l
# u
# alnum u
# m
# alnum m
# e
# alnum e
#
# >
# =
#
# 1
# alnum 1
# 0
# alnum 0
# 0
# alnum 0
#
# a
# alnum a
# n
# alnum n
# d
# alnum d
#
# n
# alnum n
# u
# alnum u
# m
# alnum m
# b
# alnum b
# e
# alnum e
# r
# alnum r
#
# <
#
# 5
# alnum 5
#
# t
# alnum t
# h
# alnum h
# e
# alnum e
# n
# alnum n
#
# b
# alnum b
# e
# alnum e
# g
# alnum g
# i
# alnum i
# n
# alnum n
# 22 volume := volume / 4;
# v
# alnum v
# o
# alnum o
# l
# alnum l
# u
# alnum u
# m
# alnum m
# e
# alnum e
#
# :
# =
#
# v
# alnum v
# o
# alnum o
# l
# alnum l
# u
# alnum u
# m
# alnum m
# e
# alnum e
#
# /
#
# 4
# alnum 4
# ;
# 23 end
# e
# alnum e
# n
# alnum n
# d
# alnum d
# 24 else begin
# e
# alnum e
# l
# alnum l
# s
# alnum s
# e
# alnum e
#
# b
# alnum b
# e
# alnum e
# g
# alnum g
# i
# alnum i
# n
# alnum n
# 25 if volume >= 50 or number < 10 then begin
# i
# alnum i
# f
# alnum f
#
# v
# alnum v
# o
# alnum o
# l
# alnum l
# u
# alnum u
# m
# alnum m
# e
# alnum e
#
# >
# =
#
# 5
# alnum 5
# 0
# alnum 0
#
# o
# alnum o
# r
# alnum r
#
# n
# alnum n
# u
# alnum u
# m
# alnum m
# b
# alnum b
# e
# alnum e
# r
# alnum r
#
# <
#
# 1
# alnum 1
# 0
# alnum 0
#
# t
# alnum t
# h
# alnum h
# e
# alnum e
# n
# alnum n
#
# b
# alnum b
# e
# alnum e
# g
# alnum g
# i
# alnum i
# n
# alnum n
# 26 volume := volume / 2;
# v
# alnum v
# o
# alnum o
# l
# alnum l
# u
# alnum u
# m
# alnum m
# e
# alnum e
#
# :
# =
#
# v
# alnum v
# o
# alnum o
# l
# alnum l
# u
# alnum u
# m
# alnum m
# e
# alnum e
#
# /
#
# 2
# alnum 2
# ;
# 27 end
# e
# alnum e
# n
# alnum n
# d
# alnum d
# 28 end;
# e
# alnum e
# n
# alnum n
# d
# alnum d
# ;
# 29 write("Factorial of ");
# w
# alnum w
# r
# alnum r
# i
# alnum i
# t
# alnum t
# e
# alnum e
# (
# "
# F
# alnum F
# a
# alnum a
# c
# alnum c
# t
# alnum t
# o
# alnum o
# r
# alnum r
# i
# alnum i
# a
# alnum a
# l
# alnum l
#
# o
# alnum o
# f
# alnum f
#
# "
# )
# ;
# 30 write(number);
# w
# alnum w
# r
# alnum r
# i
# alnum i
# t
# alnum t
# e
# alnum e
# (
# n
# alnum n
# u
# alnum u
# m
# alnum m
# b
# alnum b
# e
# alnum e
# r
# alnum r
# )
# ;
# 31 write(" is ");
# w
# alnum w
# r
# alnum r
# i
# alnum i
# t
# alnum t
# e
# alnum e
# (
# "
#
# i
# alnum i
# s
# alnum s
#
# "
# )
# ;
# 32 writeln(factorial);
# w
# alnum w
# r
# alnum r
# i
# alnum i
# t
# alnum t
# e
# alnum e
# l
# alnum l
# n
# alnum n
# (
# f
# alnum f
# a
# alnum a
# c
# alnum c
# t
# alnum t
# o
# alnum o
# r
# alnum r
# i
# alnum i
# a
# alnum a
# l
# alnum l
# )
# ;
# 33 write("Some odd value is: ");
# w
# alnum w
# r
# alnum r
# i
# alnum i
# t
# alnum t
# e
# alnum e
# (
# "
# S
# alnum S
# o
# alnum o
# m
# alnum m
# e
# alnum e
#
# o
# alnum o
# d
# alnum d
# d
# alnum d
#
# v
# alnum v
# a
# alnum a
# l
# alnum l
# u
# alnum u
# e
# alnum e
#
# i
# alnum i
# s
# alnum s
# :
#
# "
# )
# ;
# 34 writeln(volume);
# w
# alnum w
# r
# alnum r
# i
# alnum i
# t
# alnum t
# e
# alnum e
# l
# alnum l
# n
# alnum n
# (
# v
# alnum v
# o
# alnum o
# l
# alnum l
# u
# alnum u
# m
# alnum m
# e
# alnum e
# )
# ;
# 35 end.
# e
# alnum e
# n
# alnum n
# d
# alnum d
# .

# %%
# all_tokens = {}
code_lines = source_text.split('\n')

for line in range(len(code_lines)):
    
    print(line, code_lines[line])
    print(re.sub('(?<=\w|\d|")([!?,:);(])', r' \1', code_lines[line]))
    
    
    j=0
# Out:
# 0 program checkMyAbility;
# program checkMyAbility ;
# 1 var
# var
# 2 counter: integer;
# counter : integer ;
# 3 number: integer;
# number : integer ;
# 4 factorial: integer;
# factorial : integer ;
# 5 height : real;
# height : real ;
# 6 width : real;
# width : real ;
# 7 breadth : real;
# breadth : real ;
# 8 volume : real;
# volume : real ;
# 9 begin
# begin
# 10 number := 6;
# number := 6 ;
# 11 counter := number;
# counter := number ;
# 12 factorial := 1
# factorial := 1
# 13 while counter > 0 do begin
# while counter > 0 do begin
# 14 number := number * counter;
# number := number * counter ;
# 15 counter := counter - 1;
# counter := counter - 1 ;
# 16 end;
# end ;
# 17 height := 8.5;
# height := 8.5 ;
# 18 width := 4.5;
# width := 4.5 ;
# 19 breadth := 2.25;
# breadth := 2.25 ;
# 20 volume := height * width * breadth;
# volume := height * width * breadth ;
# 21 if volume >= 100 and number < 5 then begin
# if volume >= 100 and number < 5 then begin
# 22 volume := volume / 4;
# volume := volume / 4 ;
# 23 end
# end
# 24 else begin
# else begin
# 25 if volume >= 50 or number < 10 then begin
# if volume >= 50 or number < 10 then begin
# 26 volume := volume / 2;
# volume := volume / 2 ;
# 27 end
# end
# 28 end;
# end ;
# 29 write("Factorial of ");
# write ("Factorial of " );
# 30 write(number);
# write (number );
# 31 write(" is ");
# write (" is " );
# 32 writeln(factorial);
# writeln (factorial );
# 33 write("Some odd value is: ");
# write ("Some odd value is : " );
# 34 writeln(volume);
# writeln (volume );
# 35 end.
# end.

# %%
code_lines = source_text.split('\n')

for i in range(len(code_lines)):
    
    print(i, code_lines[i])
    j=0
    
    while(j!= len(code_lines[i])-1):
        
        print(code_lines[i][j])
        single_char = code_lines[i][j]
        next_char = code_lines[i][j+1]
        double = code_lines[i][j]+code_lines[i][j+1]
        
        print('->', single_char, double)
        if(double in tokens.keys()):
            print('----',tokens[double], i, j, '--', double)
            j+=2
            
        elif(single_char in tokens.keys()):
            print('----',tokens[single_char], i, j, '--', single_char)
            
        j+=1
# Out:
# 0 program checkMyAbility;
# p
# -> p pr
# r
# -> r ro
# o
# -> o og
# g
# -> g gr
# r
# -> r ra
# a
# -> a am
# m
# -> m m
#
# ->    c
# c
# -> c ch
# h
# -> h he
# e
# -> e ec
# c
# -> c ck
# k
# -> k kM
# M
# -> M My
# y
# -> y yA
# A
# -> A Ab
# b
# -> b bi
# i
# -> i il
# l
# -> l li
# i
# -> i it
# t
# -> t ty
# y
# -> y y;
# 1 var
# v
# -> v va
# a
# -> a ar
# 2 counter: integer;
# c
# -> c co
# o
# -> o ou
# u
# -> u un
# n
# -> n nt
# t
# -> t te
# e
# -> e er
# r
# -> r r:
# :
# -> : :
# ---- COLON 2 7 -- :
#
# ->    i
# i
# -> i in
# n
# -> n nt
# t
# -> t te
# e
# -> e eg
# g
# -> g ge
# e
# -> e er
# r
# -> r r;
# 3 number: integer;
# n
# -> n nu
# u
# -> u um
# m
# -> m mb
# b
# -> b be
# e
# -> e er
# r
# -> r r:
# :
# -> : :
# ---- COLON 3 6 -- :
#
# ->    i
# i
# -> i in
# n
# -> n nt
# t
# -> t te
# e
# -> e eg
# g
# -> g ge
# e
# -> e er
# r
# -> r r;
# 4 factorial: integer;
# f
# -> f fa
# a
# -> a ac
# c
# -> c ct
# t
# -> t to
# o
# -> o or
# r
# -> r ri
# i
# -> i ia
# a
# -> a al
# l
# -> l l:
# :
# -> : :
# ---- COLON 4 9 -- :
#
# ->    i
# i
# -> i in
# n
# -> n nt
# t
# -> t te
# e
# -> e eg
# g
# -> g ge
# e
# -> e er
# r
# -> r r;
# 5 height : real;
# h
# -> h he
# e
# -> e ei
# i
# -> i ig
# g
# -> g gh
# h
# -> h ht
# t
# -> t t
#
# ->    :
# :
# -> : :
# ---- COLON 5 7 -- :
#
# ->    r
# r
# -> r re
# e
# -> e ea
# a
# -> a al
# l
# -> l l;
# 6 width : real;
# w
# -> w wi
# i
# -> i id
# d
# -> d dt
# t
# -> t th
# h
# -> h h
#
# ->    :
# :
# -> : :
# ---- COLON 6 6 -- :
#
# ->    r
# r
# -> r re
# e
# -> e ea
# a
# -> a al
# l
# -> l l;
# 7 breadth : real;
# b
# -> b br
# r
# -> r re
# e
# -> e ea
# a
# -> a ad
# d
# -> d dt
# t
# -> t th
# h
# -> h h
#
# ->    :
# :
# -> : :
# ---- COLON 7 8 -- :
#
# ->    r
# r
# -> r re
# e
# -> e ea
# a
# -> a al
# l
# -> l l;
# 8 volume : real;
# v
# -> v vo
# o
# -> o ol
# l
# -> l lu
# u
# -> u um
# m
# -> m me
# e
# -> e e
#
# ->    :
# :
# -> : :
# ---- COLON 8 7 -- :
#
# ->    r
# r
# -> r re
# e
# -> e ea
# a
# -> a al
# l
# -> l l;
# 9 begin
# b
# -> b be
# e
# -> e eg
# g
# -> g gi
# i
# -> i in
# 10 number := 6;
# n
# -> n nu
# u
# -> u um
# m
# -> m mb
# b
# -> b be
# e
# -> e er
# r
# -> r r
#
# ->    :
# :
# -> : :=
# ---- ASSIGN 10 7 -- :=
# 6
# -> 6 6;
# 11 counter := number;
# c
# -> c co
# o
# -> o ou
# u
# -> u un
# n
# -> n nt
# t
# -> t te
# e
# -> e er
# r
# -> r r
#
# ->    :
# :
# -> : :=
# ---- ASSIGN 11 8 -- :=
# n
# -> n nu
# u
# -> u um
# m
# -> m mb
# b
# -> b be
# e
# -> e er
# r
# -> r r;
# 12 factorial := 1
# f
# -> f fa
# a
# -> a ac
# c
# -> c ct
# t
# -> t to
# o
# -> o or
# r
# -> r ri
# i
# -> i ia
# a
# -> a al
# l
# -> l l
#
# ->    :
# :
# -> : :=
# ---- ASSIGN 12 10 -- :=
# 13 while counter > 0 do begin
# w
# -> w wh
# h
# -> h hi
# i
# -> i il
# l
# -> l le
# e
# -> e e
#
# ->    c
# c
# -> c co
# o
# -> o ou
# u
# -> u un
# n
# -> n nt
# t
# -> t te
# e
# -> e er
# r
# -> r r
#
# ->    >
# >
# -> > >
# ---- GT 13 14 -- >
#
# ->    0
# 0
# -> 0 0
#
# ->    d
# d
# -> d do
# o
# -> o o
#
# ->    b
# b
# -> b be
# e
# -> e eg
# g
# -> g gi
# i
# -> i in
# 14 number := number * counter;
# n
# -> n nu
# u
# -> u um
# m
# -> m mb
# b
# -> b be
# e
# -> e er
# r
# -> r r
#
# ->    :
# :
# -> : :=
# ---- ASSIGN 14 7 -- :=
# n
# -> n nu
# u
# -> u um
# m
# -> m mb
# b
# -> b be
# e
# -> e er
# r
# -> r r
#
# ->    *
# *
# -> * *
# ---- MUL 14 17 -- *
#
# ->    c
# c
# -> c co
# o
# -> o ou
# u
# -> u un
# n
# -> n nt
# t
# -> t te
# e
# -> e er
# r
# -> r r;
# 15 counter := counter - 1;
# c
# -> c co
# o
# -> o ou
# u
# -> u un
# n
# -> n nt
# t
# -> t te
# e
# -> e er
# r
# -> r r
#
# ->    :
# :
# -> : :=
# ---- ASSIGN 15 8 -- :=
# c
# -> c co
# o
# -> o ou
# u
# -> u un
# n
# -> n nt
# t
# -> t te
# e
# -> e er
# r
# -> r r
#
# ->    -
# -
# -> - -
# ---- MINUS 15 19 -- -
#
# ->    1
# 1
# -> 1 1;
# 16 end;
# e
# -> e en
# n
# -> n nd
# d
# -> d d;
# 17 height := 8.5;
# h
# -> h he
# e
# -> e ei
# i
# -> i ig
# g
# -> g gh
# h
# -> h ht
# t
# -> t t
#
# ->    :
# :
# -> : :=
# ---- ASSIGN 17 7 -- :=
# 8
# -> 8 8.
# .
# -> . .5
# ---- DOT 17 11 -- .
# 5
# -> 5 5;
# 18 width := 4.5;
# w
# -> w wi
# i
# -> i id
# d
# -> d dt
# t
# -> t th
# h
# -> h h
#
# ->    :
# :
# -> : :=
# ---- ASSIGN 18 6 -- :=
# 4
# -> 4 4.
# .
# -> . .5
# ---- DOT 18 10 -- .
# 5
# -> 5 5;
# 19 breadth := 2.25;
# b
# -> b br
# r
# -> r re
# e
# -> e ea
# a
# -> a ad
# d
# -> d dt
# t
# -> t th
# h
# -> h h
#
# ->    :
# :
# -> : :=
# ---- ASSIGN 19 8 -- :=
# 2
# -> 2 2.
# .
# -> . .2
# ---- DOT 19 12 -- .
# 2
# -> 2 25
# 5
# -> 5 5;
# 20 volume := height * width * breadth;
# v
# -> v vo
# o
# -> o ol
# l
# -> l lu
# u
# -> u um
# m
# -> m me
# e
# -> e e
#
# ->    :
# :
# -> : :=
# ---- ASSIGN 20 7 -- :=
# h
# -> h he
# e
# -> e ei
# i
# -> i ig
# g
# -> g gh
# h
# -> h ht
# t
# -> t t
#
# ->    *
# *
# -> * *
# ---- MUL 20 17 -- *
#
# ->    w
# w
# -> w wi
# i
# -> i id
# d
# -> d dt
# t
# -> t th
# h
# -> h h
#
# ->    *
# *
# -> * *
# ---- MUL 20 25 -- *
#
# ->    b
# b
# -> b br
# r
# -> r re
# e
# -> e ea
# a
# -> a ad
# d
# -> d dt
# t
# -> t th
# h
# -> h h;
# 21 if volume >= 100 and number < 5 then begin
# i
# -> i if
# f
# -> f f
#
# ->    v
# v
# -> v vo
# o
# -> o ol
# l
# -> l lu
# u
# -> u um
# m
# -> m me
# e
# -> e e
#
# ->    >
# >
# -> > >=
# ---- GTE 21 10 -- >=
# 1
# -> 1 10
# 0
# -> 0 00
# 0
# -> 0 0
#
# ->    a
# a
# -> a an
# n
# -> n nd
# d
# -> d d
#
# ->    n
# n
# -> n nu
# u
# -> u um
# m
# -> m mb
# b
# -> b be
# e
# -> e er
# r
# -> r r
#
# ->    <
# <
# -> < <
# ---- LT 21 28 -- <
#
# ->    5
# 5
# -> 5 5
#
# ->    t
# t
# -> t th
# h
# -> h he
# e
# -> e en
# n
# -> n n
#
# ->    b
# b
# -> b be
# e
# -> e eg
# g
# -> g gi
# i
# -> i in
# 22 volume := volume / 4;
# v
# -> v vo
# o
# -> o ol
# l
# -> l lu
# u
# -> u um
# m
# -> m me
# e
# -> e e
#
# ->    :
# :
# -> : :=
# ---- ASSIGN 22 7 -- :=
# v
# -> v vo
# o
# -> o ol
# l
# -> l lu
# u
# -> u um
# m
# -> m me
# e
# -> e e
#
# ->    /
# /
# -> / /
# ---- DIV 22 17 -- /
#
# ->    4
# 4
# -> 4 4;
# 23 end
# e
# -> e en
# n
# -> n nd
# 24 else begin
# e
# -> e el
# l
# -> l ls
# s
# -> s se
# e
# -> e e
#
# ->    b
# b
# -> b be
# e
# -> e eg
# g
# -> g gi
# i
# -> i in
# 25 if volume >= 50 or number < 10 then begin
# i
# -> i if
# f
# -> f f
#
# ->    v
# v
# -> v vo
# o
# -> o ol
# l
# -> l lu
# u
# -> u um
# m
# -> m me
# e
# -> e e
#
# ->    >
# >
# -> > >=
# ---- GTE 25 10 -- >=
# 5
# -> 5 50
# 0
# -> 0 0
#
# ->    o
# o
# -> o or
# r
# -> r r
#
# ->    n
# n
# -> n nu
# u
# -> u um
# m
# -> m mb
# b
# -> b be
# e
# -> e er
# r
# -> r r
#
# ->    <
# <
# -> < <
# ---- LT 25 26 -- <
#
# ->    1
# 1
# -> 1 10
# 0
# -> 0 0
#
# ->    t
# t
# -> t th
# h
# -> h he
# e
# -> e en
# n
# -> n n
#
# ->    b
# b
# -> b be
# e
# -> e eg
# g
# -> g gi
# i
# -> i in
# 26 volume := volume / 2;
# v
# -> v vo
# o
# -> o ol
# l
# -> l lu
# u
# -> u um
# m
# -> m me
# e
# -> e e
#
# ->    :
# :
# -> : :=
# ---- ASSIGN 26 7 -- :=
# v
# -> v vo
# o
# -> o ol
# l
# -> l lu
# u
# -> u um
# m
# -> m me
# e
# -> e e
#
# ->    /
# /
# -> / /
# ---- DIV 26 17 -- /
#
# ->    2
# 2
# -> 2 2;
# 27 end
# e
# -> e en
# n
# -> n nd
# 28 end;
# e
# -> e en
# n
# -> n nd
# d
# -> d d;
# 29 write("Factorial of ");
# w
# -> w wr
# r
# -> r ri
# i
# -> i it
# t
# -> t te
# e
# -> e e(
# (
# -> ( ("
# ---- LPAREN 29 5 -- (
# "
# -> " "F
# F
# -> F Fa
# a
# -> a ac
# c
# -> c ct
# t
# -> t to
# o
# -> o or
# r
# -> r ri
# i
# -> i ia
# a
# -> a al
# l
# -> l l
#
# ->    o
# o
# -> o of
# f
# -> f f
#
# ->    "
# "
# -> " ")
# )
# -> ) );
# ---- RPAREN 29 21 -- )
# 30 write(number);
# w
# -> w wr
# r
# -> r ri
# i
# -> i it
# t
# -> t te
# e
# -> e e(
# (
# -> ( (n
# ---- LPAREN 30 5 -- (
# n
# -> n nu
# u
# -> u um
# m
# -> m mb
# b
# -> b be
# e
# -> e er
# r
# -> r r)
# )
# -> ) );
# ---- RPAREN 30 12 -- )
# 31 write(" is ");
# w
# -> w wr
# r
# -> r ri
# i
# -> i it
# t
# -> t te
# e
# -> e e(
# (
# -> ( ("
# ---- LPAREN 31 5 -- (
# "
# -> " "
#
# ->    i
# i
# -> i is
# s
# -> s s
#
# ->    "
# "
# -> " ")
# )
# -> ) );
# ---- RPAREN 31 12 -- )
# 32 writeln(factorial);
# w
# -> w wr
# r
# -> r ri
# i
# -> i it
# t
# -> t te
# e
# -> e el
# l
# -> l ln
# n
# -> n n(
# (
# -> ( (f
# ---- LPAREN 32 7 -- (
# f
# -> f fa
# a
# -> a ac
# c
# -> c ct
# t
# -> t to
# o
# -> o or
# r
# -> r ri
# i
# -> i ia
# a
# -> a al
# l
# -> l l)
# )
# -> ) );
# ---- RPAREN 32 17 -- )
# 33 write("Some odd value is: ");
# w
# -> w wr
# r
# -> r ri
# i
# -> i it
# t
# -> t te
# e
# -> e e(
# (
# -> ( ("
# ---- LPAREN 33 5 -- (
# "
# -> " "S
# S
# -> S So
# o
# -> o om
# m
# -> m me
# e
# -> e e
#
# ->    o
# o
# -> o od
# d
# -> d dd
# d
# -> d d
#
# ->    v
# v
# -> v va
# a
# -> a al
# l
# -> l lu
# u
# -> u ue
# e
# -> e e
#
# ->    i
# i
# -> i is
# s
# -> s s:
# :
# -> : :
# ---- COLON 33 24 -- :
#
# ->    "
# "
# -> " ")
# )
# -> ) );
# ---- RPAREN 33 27 -- )
# 34 writeln(volume);
# w
# -> w wr
# r
# -> r ri
# i
# -> i it
# t
# -> t te
# e
# -> e el
# l
# -> l ln
# n
# -> n n(
# (
# -> ( (v
# ---- LPAREN 34 7 -- (
# v
# -> v vo
# o
# -> o ol
# l
# -> l lu
# u
# -> u um
# m
# -> m me
# e
# -> e e)
# )
# -> ) );
# ---- RPAREN 34 14 -- )
# 35 end.
# e
# -> e en
# n
# -> n nd
# d
# -> d d.

# %%
for i in range(len(code_lines)):
    
    print(i, code_lines[i])
    j=0
    
    while(j < len(code_lines[i])):
        
        print(code_lines[i][j])
        single_char = code_lines[i][j]
        
        if((j+1) < len(code_lines[i])):
            double = code_lines[i][j]+code_lines[i][j+1]
        else:
            double = '-1'
            
        if(double in tokens.keys()):
            print('----',tokens[double], i, j, '--', double)
            j+=2
            
        elif(single_char in tokens.keys()):
            print('----',tokens[single_char], i, j, '--', single_char)
        
        j+=1
# Out:
# 0 program checkMyAbility;
# p
# r
# o
# g
# r
# a
# m
#
# c
# h
# e
# c
# k
# M
# y
# A
# b
# i
# l
# i
# t
# y
# ;
# ---- SEMICOLON 0 22 -- ;
# 1 var
# v
# a
# r
# 2 counter: integer;
# c
# o
# u
# n
# t
# e
# r
# :
# ---- COLON 2 7 -- :
#
# i
# n
# t
# e
# g
# e
# r
# ;
# ---- SEMICOLON 2 16 -- ;
# 3 number: integer;
# n
# u
# m
# b
# e
# r
# :
# ---- COLON 3 6 -- :
#
# i
# n
# t
# e
# g
# e
# r
# ;
# ---- SEMICOLON 3 15 -- ;
# 4 factorial: integer;
# f
# a
# c
# t
# o
# r
# i
# a
# l
# :
# ---- COLON 4 9 -- :
#
# i
# n
# t
# e
# g
# e
# r
# ;
# ---- SEMICOLON 4 18 -- ;
# 5 height : real;
# h
# e
# i
# g
# h
# t
#
# :
# ---- COLON 5 7 -- :
#
# r
# e
# a
# l
# ;
# ---- SEMICOLON 5 13 -- ;
# 6 width : real;
# w
# i
# d
# t
# h
#
# :
# ---- COLON 6 6 -- :
#
# r
# e
# a
# l
# ;
# ---- SEMICOLON 6 12 -- ;
# 7 breadth : real;
# b
# r
# e
# a
# d
# t
# h
#
# :
# ---- COLON 7 8 -- :
#
# r
# e
# a
# l
# ;
# ---- SEMICOLON 7 14 -- ;
# 8 volume : real;
# v
# o
# l
# u
# m
# e
#
# :
# ---- COLON 8 7 -- :
#
# r
# e
# a
# l
# ;
# ---- SEMICOLON 8 13 -- ;
# 9 begin
# b
# e
# g
# i
# n
# 10 number := 6;
# n
# u
# m
# b
# e
# r
#
# :
# ---- ASSIGN 10 7 -- :=
# 6
# ;
# ---- SEMICOLON 10 11 -- ;
# 11 counter := number;
# c
# o
# u
# n
# t
# e
# r
#
# :
# ---- ASSIGN 11 8 -- :=
# n
# u
# m
# b
# e
# r
# ;
# ---- SEMICOLON 11 17 -- ;
# 12 factorial := 1
# f
# a
# c
# t
# o
# r
# i
# a
# l
#
# :
# ---- ASSIGN 12 10 -- :=
# 1
# 13 while counter > 0 do begin
# w
# h
# i
# l
# e
#
# c
# o
# u
# n
# t
# e
# r
#
# >
# ---- GT 13 14 -- >
#
# 0
#
# d
# o
#
# b
# e
# g
# i
# n
# 14 number := number * counter;
# n
# u
# m
# b
# e
# r
#
# :
# ---- ASSIGN 14 7 -- :=
# n
# u
# m
# b
# e
# r
#
# *
# ---- MUL 14 17 -- *
#
# c
# o
# u
# n
# t
# e
# r
# ;
# ---- SEMICOLON 14 26 -- ;
# 15 counter := counter - 1;
# c
# o
# u
# n
# t
# e
# r
#
# :
# ---- ASSIGN 15 8 -- :=
# c
# o
# u
# n
# t
# e
# r
#
# -
# ---- MINUS 15 19 -- -
#
# 1
# ;
# ---- SEMICOLON 15 22 -- ;
# 16 end;
# e
# n
# d
# ;
# ---- SEMICOLON 16 3 -- ;
# 17 height := 8.5;
# h
# e
# i
# g
# h
# t
#
# :
# ---- ASSIGN 17 7 -- :=
# 8
# .
# ---- DOT 17 11 -- .
# 5
# ;
# ---- SEMICOLON 17 13 -- ;
# 18 width := 4.5;
# w
# i
# d
# t
# h
#
# :
# ---- ASSIGN 18 6 -- :=
# 4
# .
# ---- DOT 18 10 -- .
# 5
# ;
# ---- SEMICOLON 18 12 -- ;
# 19 breadth := 2.25;
# b
# r
# e
# a
# d
# t
# h
#
# :
# ---- ASSIGN 19 8 -- :=
# 2
# .
# ---- DOT 19 12 -- .
# 2
# 5
# ;
# ---- SEMICOLON 19 15 -- ;
# 20 volume := height * width * breadth;
# v
# o
# l
# u
# m
# e
#
# :
# ---- ASSIGN 20 7 -- :=
# h
# e
# i
# g
# h
# t
#
# *
# ---- MUL 20 17 -- *
#
# w
# i
# d
# t
# h
#
# *
# ---- MUL 20 25 -- *
#
# b
# r
# e
# a
# d
# t
# h
# ;
# ---- SEMICOLON 20 34 -- ;
# 21 if volume >= 100 and number < 5 then begin
# i
# f
#
# v
# o
# l
# u
# m
# e
#
# >
# ---- GTE 21 10 -- >=
# 1
# 0
# 0
#
# a
# n
# d
#
# n
# u
# m
# b
# e
# r
#
# <
# ---- LT 21 28 -- <
#
# 5
#
# t
# h
# e
# n
#
# b
# e
# g
# i
# n
# 22 volume := volume / 4;
# v
# o
# l
# u
# m
# e
#
# :
# ---- ASSIGN 22 7 -- :=
# v
# o
# l
# u
# m
# e
#
# /
# ---- DIV 22 17 -- /
#
# 4
# ;
# ---- SEMICOLON 22 20 -- ;
# 23 end
# e
# n
# d
# 24 else begin
# e
# l
# s
# e
#
# b
# e
# g
# i
# n
# 25 if volume >= 50 or number < 10 then begin
# i
# f
#
# v
# o
# l
# u
# m
# e
#
# >
# ---- GTE 25 10 -- >=
# 5
# 0
#
# o
# r
#
# n
# u
# m
# b
# e
# r
#
# <
# ---- LT 25 26 -- <
#
# 1
# 0
#
# t
# h
# e
# n
#
# b
# e
# g
# i
# n
# 26 volume := volume / 2;
# v
# o
# l
# u
# m
# e
#
# :
# ---- ASSIGN 26 7 -- :=
# v
# o
# l
# u
# m
# e
#
# /
# ---- DIV 26 17 -- /
#
# 2
# ;
# ---- SEMICOLON 26 20 -- ;
# 27 end
# e
# n
# d
# 28 end;
# e
# n
# d
# ;
# ---- SEMICOLON 28 3 -- ;
# 29 write("Factorial of ");
# w
# r
# i
# t
# e
# (
# ---- LPAREN 29 5 -- (
# "
# F
# a
# c
# t
# o
# r
# i
# a
# l
#
# o
# f
#
# "
# )
# ---- RPAREN 29 21 -- )
# ;
# ---- SEMICOLON 29 22 -- ;
# 30 write(number);
# w
# r
# i
# t
# e
# (
# ---- LPAREN 30 5 -- (
# n
# u
# m
# b
# e
# r
# )
# ---- RPAREN 30 12 -- )
# ;
# ---- SEMICOLON 30 13 -- ;
# 31 write(" is ");
# w
# r
# i
# t
# e
# (
# ---- LPAREN 31 5 -- (
# "
#
# i
# s
#
# "
# )
# ---- RPAREN 31 12 -- )
# ;
# ---- SEMICOLON 31 13 -- ;
# 32 writeln(factorial);
# w
# r
# i
# t
# e
# l
# n
# (
# ---- LPAREN 32 7 -- (
# f
# a
# c
# t
# o
# r
# i
# a
# l
# )
# ---- RPAREN 32 17 -- )
# ;
# ---- SEMICOLON 32 18 -- ;
# 33 write("Some odd value is: ");
# w
# r
# i
# t
# e
# (
# ---- LPAREN 33 5 -- (
# "
# S
# o
# m
# e
#
# o
# d
# d
#
# v
# a
# l
# u
# e
#
# i
# s
# :
# ---- COLON 33 24 -- :
#
# "
# )
# ---- RPAREN 33 27 -- )
# ;
# ---- SEMICOLON 33 28 -- ;
# 34 writeln(volume);
# w
# r
# i
# t
# e
# l
# n
# (
# ---- LPAREN 34 7 -- (
# v
# o
# l
# u
# m
# e
# )
# ---- RPAREN 34 14 -- )
# ;
# ---- SEMICOLON 34 15 -- ;
# 35 end.
# e
# n
# d
# .
# ---- DOT 35 3 -- .
